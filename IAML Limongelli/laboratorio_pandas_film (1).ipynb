# %% [markdown]
# # Laboratorio su Pandas: Analisi di un dataset di film

# %%
# Import delle librerie necessarie
import pandas as pd
import matplotlib.pyplot as plt

# Caricamento del dataset
df = pd.read_csv("dataset_film.csv")
df.head()

# %% [markdown]
# ## 1. Esplorazione del dataset

# %% [markdown]
# **Esercizi:**
# 1. Mostra le prime e le ultime righe del dataset.
# 2. Quante righe e colonne ha il dataset? (`shape`)
# 3. Quali tipi di dati contiene? (`dtypes`)
# 4. Calcola statistiche di base sulle colonne numeriche (`describe()`).
# 5. Quali informazioni generali puoi ottenere con `info()`?

# %% [markdown]
# ## 2. Selezione e filtraggio

# %% [markdown]
# **Esercizi:**
# 1. Visualizza solo le colonne `Titolo` e `Anno`.
# 2. Estrai tutti i film diretti da *Christopher Nolan*.
# 3. Estrai i film prodotti dopo il 2010.
# 4. Mostra i film con durata superiore a 150 minuti e prodotti negli USA.

# %% [markdown]
# ## 3. Pulizia e trasformazione

# %% [markdown]
# **Esercizi:**
# 1. Aggiungi una colonna “Decennio” calcolata a partire dall’anno.
# 2. Crea una colonna “FilmLungo” che vale True se la durata > 150 minuti.
# 3. Combina attore e attrice in una nuova colonna “CoppiaProtagonisti”.
# 4. Ordina i film per anno e poi per durata.

# %% [markdown]
# ## 4. Analisi statistica

# %% [markdown]
# **Esercizi:**
# 1. Calcola la durata media dei film.
# 2. Calcola la durata media per stato di produzione (`groupby`).
# 3. Trova il regista con il maggior numero di film nel dataset.
# 4. Calcola la durata media dei film per decennio.

# %% [markdown]
# ## 5. Visualizzazione dei dati

# %% [markdown]
# **Esercizi:**
# 1. Crea un grafico a barre con il numero di film per regista.
# 2. Crea un istogramma delle durate.
# 3. Crea un boxplot della durata per stato di produzione.
# 4. (Facoltativo) Crea un grafico a dispersione Anno–Durata.

# %% [markdown]
# Rispondi alle seguenti domande:
# - Quali registi tendono a produrre film più lunghi?
# - Come varia la durata media dei film nel tempo?
# - Quali stati di produzione sono più presenti nel dataset?
